# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import (precision_recall_curve,
                             PrecisionRecallDisplay,
                             accuracy_score)
# from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_csv('../csvs/fraudTrain.csv')
df
# Out:
#          Unnamed: 0 trans_date_trans_time        cc_num  \
# 0                 0      01/01/2019 00:00  2.703190e+15
# 1                 1      01/01/2019 00:00  6.304230e+11
# 2                 2      01/01/2019 00:00  3.885950e+13
# 3                 3      01/01/2019 00:01  3.534090e+15
# 4                 4      01/01/2019 00:03  3.755340e+14
# ...             ...                   ...           ...
# 1048570     1048570      10/03/2020 16:07  6.011980e+15
# 1048571     1048571      10/03/2020 16:07  4.839040e+15
# 1048572     1048572      10/03/2020 16:08  5.718440e+11
# 1048573     1048573      10/03/2020 16:08  4.646850e+18
# 1048574     1048574      10/03/2020 16:08  2.283740e+15
#
#                                    merchant        category     amt  \
# 0                fraud_Rippin, Kub and Mann        misc_net    4.97
# 1           fraud_Heller, Gutmann and Zieme     grocery_pos  107.23
# 2                      fraud_Lind-Buckridge   entertainment  220.11
# 3        fraud_Kutch, Hermiston and Farrell   gas_transport   45.00
# 4                       fraud_Keeling-Crist        misc_pos   41.96
# ...                                     ...             ...     ...
# 1048570                     fraud_Fadel Inc  health_fitness   77.00
# 1048571    fraud_Cremin, Hamill and Reichel        misc_pos  116.94
# 1048572  fraud_O'Connell, Botsford and Hand            home   21.27
# 1048573              fraud_Thompson-Gleason  health_fitness    9.52
# 1048574                 fraud_Buckridge PLC        misc_pos    6.81
#
#              first      last gender                            street  ...  \
# 0         Jennifer     Banks      F                    561 Perry Cove  ...
# 1        Stephanie      Gill      F      43039 Riley Greens Suite 393  ...
# 2           Edward   Sanchez      M          594 White Dale Suite 530  ...
# 3           Jeremy     White      M       9443 Cynthia Court Apt. 038  ...
# 4            Tyler    Garcia      M                  408 Bradley Rest  ...
# ...            ...       ...    ...                               ...  ...
# 1048570      Haley    Wagner      F            05561 Farrell Crescent  ...
# 1048571   Meredith  Campbell      F               043 Hanson Turnpike  ...
# 1048572      Susan     Mills      F                  005 Cody Estates  ...
# 1048573      Julia      Bell      F               576 House Crossroad  ...
# 1048574    Shannon  Williams      F  9345 Spencer Junctions Suite 183  ...
#
#              lat      long  city_pop                                job  \
# 0        36.0788  -81.1781      3495          Psychologist, counselling
# 1        48.8878 -118.2105       149  Special educational needs teacher
# 2        42.1808 -112.2620      4154        Nature conservation officer
# 3        46.2306 -112.1138      1939                    Patent attorney
# 4        38.4207  -79.4629        99     Dance movement psychotherapist
# ...          ...       ...       ...                                ...
# 1048570  39.0305  -76.5515     92106    Accountant, chartered certified
# 1048571  41.1826  -92.3097      1583                         Geochemist
# 1048572  38.2507  -85.7476    736284              Engineering geologist
# 1048573  40.7320  -73.1000      4056                  Film/video editor
# 1048574  34.0770  -84.3033    165556                     Prison officer
#
#                 dob                         trans_num   unix_time  merch_lat  \
# 0        09/03/1988  0b242abb623afc578575680df30655b9  1325376018  36.011293
# 1        21/06/1978  1f76529f8574734946361c461b024d99  1325376044  49.159047
# 2        19/01/1962  a1a22d70485983eac12b5b88dad1cf95  1325376051  43.150704
# 3        12/01/1967  6b849c168bdad6f867558c3793159a81  1325376076  47.034331
# 4        28/03/1986  a41d7549acf90789359a9aa5346dcb46  1325376186  38.674999
# ...             ...                               ...         ...        ...
# 1048570  28/05/1943  45ecd198c65e81e597db22e8d2ef7361  1362931649  38.779464
# 1048571  28/06/1999  c00ce51c6ebb7657474a77b9e0b51f34  1362931670  41.400318
# 1048572  02/04/1952  17c9dc8b2a6449ca2473726346e58e6c  1362931711  37.293339
# 1048573  25/06/1990  5ca650881b48a6a38754f841c23b77ab  1362931718  39.773077
# 1048574  27/12/1997  8d0a575fe635bbde12f1a2bffc126731  1362931730  33.601468
#
#          merch_long  is_fraud
# 0        -82.048315         0
# 1       -118.186462         0
# 2       -112.154481         0
# 3       -112.561071         0
# 4        -78.632459         0
# ...             ...       ...
# 1048570  -76.317042         0
# 1048571  -92.726724         0
# 1048572  -84.798122         0
# 1048573  -72.213209         0
# 1048574  -83.891921         0
#
# [1048575 rows x 23 columns]

# %%
fraud_trans = df[df['is_fraud'] == 1]
non_fraud_trans = df[df['is_fraud'] == 0]

len_fraud = len(fraud_trans)
rand_non_fraud = non_fraud_trans.sample(n=len_fraud, random_state=42)

balanced_df = pd.concat([fraud_trans, rand_non_fraud])

balanced_df = balanced_df.sort_values('unix_time').reset_index(drop=True)
balanced_df
# Out:
#        Unnamed: 0 trans_date_trans_time        cc_num  \
# 0             554      01/01/2019 07:14  4.239550e+15
# 1             634      01/01/2019 08:14  3.023500e+13
# 2             891      01/01/2019 11:16  3.500170e+15
# 3             937      01/01/2019 11:52  4.653880e+15
# 4            1097      01/01/2019 13:27  3.059650e+13
# ...           ...                   ...           ...
# 12007     1048171      10/03/2020 13:44  3.438190e+14
# 12008     1048179      10/03/2020 13:46  4.653880e+15
# 12009     1048222      10/03/2020 14:00  3.672270e+13
# 12010     1048251      10/03/2020 14:11  2.131200e+14
# 12011     1048408      10/03/2020 15:04  4.683640e+12
#
#                                 merchant       category     amt    first  \
# 0                   fraud_Kiehn-Emmerich    grocery_pos   67.98     Carl
# 1                   fraud_Kiehn-Emmerich    grocery_pos   45.74  Matthew
# 2                   fraud_Corwin-Collins  gas_transport   79.13    Ricky
# 3                  fraud_Brekke and Sons  gas_transport   44.35   Monica
# 4      fraud_Bradtke, Torp and Bahringer  personal_care   20.27   Daniel
# ...                                  ...            ...     ...      ...
# 12007                   fraud_Larkin Ltd      kids_pets   38.32   Shelby
# 12008                fraud_Heathcote LLC   shopping_net  217.68   Monica
# 12009                     fraud_Auer LLC  personal_care   78.12  Jessica
# 12010                  fraud_Kutch-Ferry           home   14.66   Willie
# 12011            fraud_Bahringer-Streich    food_dining   54.66   Daniel
#
#             last gender                             street  ...      lat  \
# 0      Hernandez      M         9134 Darryl Flat Suite 916  ...  41.1410
# 1        Lambert      M        7188 Melissa Crest Apt. 151  ...  43.9446
# 2           Dunn      M         97689 Davis Point Apt. 967  ...  42.3669
# 3         Tucker      F              302 Christina Islands  ...  37.0581
# 4         Graham      M         28223 Ward Summit Apt. 664  ...  39.8422
# ...          ...    ...                                ...  ...      ...
# 12007     Cannon      F          1535 Ryan Burgs Suite 919  ...  41.5855
# 12008     Tucker      F              302 Christina Islands  ...  37.0581
# 12009      Perez      F  8172 Robertson Parkways Suite 072  ...  33.2887
# 12010     Jordan      M                       529 West Key  ...  32.9550
# 12011       Boyd      M               8925 Nicholas Points  ...  30.2510
#
#            long  city_pop                       job         dob  \
# 0      -84.5722      6284  Secondary school teacher  27/03/1936
# 1      -88.0911      5196     Child psychotherapist  22/01/1978
# 2      -82.9938    673342            Health visitor  02/09/1983
# 3      -86.1938      6841         Therapist, sports  06/06/1999
# 4     -105.1097    122111             Hotel manager  23/05/1987
# ...         ...       ...                       ...         ...
# 12007  -93.6719    222785        Wellsite geologist  24/01/1956
# 12008  -86.1938      6841         Therapist, sports  06/06/1999
# 12009 -111.0985      2872        Petroleum engineer  28/10/1987
# 12010  -92.5870      1758    Psychologist, forensic  08/08/1957
# 12011  -92.5002      1261       Broadcast presenter  01/07/1972
#
#                               trans_num   unix_time  merch_lat  merch_long  \
# 0      5ea3a2326411e4781bef4be5bd3f4b07  1325402088  41.493388  -84.559550
# 1      8f3ceb87bc39e9b80f291ac4fc1263fb  1325405672  43.965711  -88.419416
# 2      bb6275160a41244c1afe7b1f7b857d7b  1325416607  41.558926  -83.545327
# 3      70d38b6b507be24872f82ce49ac694ca  1325418779  36.301043  -86.692419
# 4      a630f354a8bf2ffaeac0628593955e50  1325424473  40.015831 -104.719839
# ...                                 ...         ...        ...         ...
# 12007  fd2a6769020261033d90930ee7fb1db7  1362923054  42.089597  -92.969306
# 12008  0c5928cc5b8a5a988d7b0e87b0513cf3  1362923190  36.573742  -86.370055
# 12009  a1e3e0f132908b347ef0c84553bb32e7  1362924040  34.010664 -110.880783
# 12010  b6209a62e128a1c95a5a5544ffd11661  1362924699  32.782321  -92.544417
# 12011  d6af544af6bc0de0390d46a0d72781ef  1362927887  29.801265  -91.755229
#
#        is_fraud
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 12007         0
# 12008         0
# 12009         0
# 12010         0
# 12011         0
#
# [12012 rows x 23 columns]

# %%
categories = balanced_df['category'].unique().tolist()
categories
# Out:
# ['grocery_pos',
#  'gas_transport',
#  'personal_care',
#  'shopping_net',
#  'travel',
#  'shopping_pos',
#  'home',
#  'kids_pets',
#  'misc_pos',
#  'grocery_net',
#  'misc_net',
#  'health_fitness',
#  'entertainment',
#  'food_dining']

# %%
balanced_df = pd.get_dummies(balanced_df, columns=['category'], drop_first=True)
balanced_df.columns
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'amt',
#        'first', 'last', 'gender', 'street', 'city', 'state', 'zip', 'lat',
#        'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time', 'merch_lat',
#        'merch_long', 'is_fraud', 'category_food_dining',
#        'category_gas_transport', 'category_grocery_net',
#        'category_grocery_pos', 'category_health_fitness', 'category_home',
#        'category_kids_pets', 'category_misc_net', 'category_misc_pos',
#        'category_personal_care', 'category_shopping_net',
#        'category_shopping_pos', 'category_travel'],
#       dtype='object')

# %%
balanced_df['category_misc_net'] = balanced_df['category_misc_net'].astype(int)
balanced_df['category_grocery_pos'] = balanced_df['category_grocery_pos'].astype(int)
balanced_df['category_gas_transport'] = balanced_df['category_gas_transport'].astype(int)

# %%
test_df = pd.read_csv('../csvs/fraudTest.csv')
test_df = pd.get_dummies(test_df, columns=['category'], drop_first=True)
test_df['category_misc_net'] = test_df['category_misc_net'].astype(int)
test_df['category_grocery_pos'] = test_df['category_grocery_pos'].astype(int)
test_df['category_gas_transport'] = test_df['category_gas_transport'].astype(int)

# %%
X_train = balanced_df[['amt', 'category_misc_net', 'category_grocery_pos', 'category_gas_transport']].values
y_train = balanced_df['is_fraud'].values
X_test = test_df[['amt', 'category_misc_net', 'category_grocery_pos', 'category_gas_transport']].values

# %%
knn = KNeighborsClassifier(n_neighbors=6)
knn.fit(X_train, y_train)

y_test = knn.predict(X_test)
y_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(555719,))

# %%
display = PrecisionRecallDisplay.from_estimator(
    knn, X_test, y_test, name="kNN", plot_chance_level=True, despine=True
)
_ = display.ax_.set_title("2-class Precision-Recall curve")
# implies a perfect model? which wth no

# %%
y_actual = test_df['is_fraud'].values
wrong_0_1 = 0
wrong_1_0 = 0
right_1 = 0
right_0 = 0

actual_1 = 0
actual_0 = 0
test_1 = 0
test_0 = 0

for x in range(len(y_actual)):
    val = y_actual[x]
    testval = y_test[x]

    if testval != val:
        if testval == 0 and val == 1:
            wrong_0_1 += 1

            test_0 += 1
            actual_1 += 1
        elif testval == 1 and val == 0:
            wrong_1_0 += 1

            test_1 += 1
            actual_0 += 1
    else:
        if testval == 1 and val == 1:
            right_1 += 1

            test_1 += 1
            actual_1 += 1
        elif testval == 0 and val == 0:
            right_0 += 1

            test_0 += 1
            actual_0 += 1


print('false positives:', wrong_1_0)
print('false negatives:', wrong_0_1)
print('overall false:', (wrong_0_1 + wrong_1_0))

print('\ntrue positives:', right_1)
print('true negatives:', right_0)
print('overall true:', (right_0 + right_1))
# many more false positives than false negatives
# many more true negatives than true positives

print('\nactual fraud/non-fraud ratio:', (actual_1 / actual_0))
print('predicted fraud/non-fraud ratio:', (test_1 / test_0))
# many more 1s in the test df

print('\nAcuraccy:')
print((right_1 + right_0) / (len(y_actual)) * 100)
# wahey, 94% acuraccy so I guess it's amazing
# this is salt in the wound, we literally had this lesson in statistics yesterday
# Out:
# false positives: 34445
# false negatives: 303
# overall false: 34748
#
# true positives: 1842
# true negatives: 519129
# overall true: 520971
#
# actual fraud/non-fraud ratio: 0.003874820710510248
# predicted fraud/non-fraud ratio: 0.06985899983058418
#
# Acuraccy:
# 93.74719957388537

# %%
accuracy_score(y_true=y_actual, y_pred=y_test) * 100
# Out:
# 93.74719957388537
